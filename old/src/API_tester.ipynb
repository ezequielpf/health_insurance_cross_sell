# %%
import requests
import pandas as pd
import pickle
from features.health_insurance import HealthInsurance
import json

# %%
df_raw = pd.read_csv('/home/ezequiel/Documentos/Comunidade_DS/health_insurance_cross_sell/data/raw/train.csv')

# %%
df_raw.shape
# Out:
# (381109, 12)

# %%
df_raw.sample(500).to_csv('./data/df_test.csv', index=False)

# %%
model = pickle.load(open('/home/ezequiel/Documentos/Comunidade_DS/health_insurance_cross_sell/models/linear_regression_model.pkl', 'rb'))

# %%
pipeline = HealthInsurance()

# %%
df_test = df_raw.copy()

# %%
df1 = HealthInsurance.columns_rename(pipeline, data=df_test)

# %%
df2 = HealthInsurance.feature_engineering(pipeline, data=df1)

# %%
df3 = HealthInsurance.data_preparation(pipeline, data=df2)

# %%
df_response = HealthInsurance.get_prediction(pipeline, model=model, original_data=df_raw, test_data=df3)

# %%
df_response

# %%
pd.DataFrame(json.loads(df_response)).head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response     score
# 0         1  0.302348
# 1         0  0.035963
# 2         1  0.300988
# 3         0  0.000628
# 4         0  0.000569

# %%
df_test = pd.read_csv('./data/df_test.csv')

# %%
#data = json.dumps(df_test.sample(500).to_dict(orient='records'))
data = df_test.sample(500).to_json(orient='records')

# %%
# API call
#url = 'http://localhost:5000/src/models'
url = 'https://health-insurance-web-app.onrender.com/predict'
header = {'Content-type': 'application/json'}

r = requests.post(url, json=data, headers=header)
#r = requests.post(url=url, json=data)
print(f'Status Code {r.status_code}')
# Out:
# Status Code 502

# %%
pd.json_normalize(r.json()).head(20).sort_values('score', ascending=False)
# Out:
#         id    gender       age  driving_license  region_code  \
# 1    76475  0.138038  0.200000                1     0.187564
# 2   135198  0.138038  0.707692                1     0.187564
# 7   247562  0.138038  0.430769                1     0.187564
# 3   130865  0.104363  0.369231                1     0.187564
# 6   247983  0.138038  0.569231                1     0.167440
# 19   57885  0.104363  0.076923                1     0.126802
# 18   92504  0.138038  0.584615                1     0.098092
# 14   32869  0.104363  0.076923                1     0.078768
# 11   27441  0.104363  0.307692                1     0.070596
# 15  169296  0.138038  0.046154                1     0.062634
# 4    89191  0.104363  0.430769                1     0.074392
# 13    8140  0.138038  0.000000                1     0.098092
# 8   288481  0.104363  0.230769                1     0.126802
# 16  202884  0.104363  0.276923                1     0.070596
# 0   234405  0.138038  0.046154                1     0.092667
# 10  187257  0.104363  0.123077                1     0.122486
# 12  178646  0.138038  0.723077                1     0.074000
# 17  294919  0.104363  0.030769                1     0.094932
# 9   338846  0.104363  0.384615                1     0.074392
# 5   378705  0.104363  0.061538                1     0.074392
#
#     previously_insured        vehicle_age  vehicle_damage  annual_premium  \
# 1                    0       below_1_year               1        0.960551
# 2                    0  between_1_2_years               1       -1.621992
# 7                    0  between_1_2_years               1        0.980524
# 3                    0  between_1_2_years               1        1.874912
# 6                    0  between_1_2_years               1        0.334061
# 19                   0       below_1_year               1        0.359318
# 18                   0  between_1_2_years               1        0.763604
# 14                   0       below_1_year               1        0.218169
# 11                   0  between_1_2_years               1       -0.276752
# 15                   0       below_1_year               0       -0.343814
# 4                    0  between_1_2_years               0       -0.331969
# 13                   1       below_1_year               0        0.154359
# 8                    1  between_1_2_years               0       -0.502265
# 16                   1  between_1_2_years               0        0.149249
# 0                    1       below_1_year               0        0.431257
# 10                   1       below_1_year               0       -0.296609
# 12                   1  between_1_2_years               0        0.635693
# 17                   1       below_1_year               0       -0.139087
# 9                    1  between_1_2_years               0        0.601611
# 5                    1       below_1_year               0        0.031267
#
#     policy_sales_channel   vintage  response     score
# 1                   61.0  0.591696         0  0.347035
# 2                  157.0  0.820069         0  0.317628
# 7                  124.0  0.169550         1  0.303761
# 3                   26.0  0.276817         0  0.279339
# 6                  124.0  0.242215         0  0.278163
# 19                  26.0  0.086505         0  0.235069
# 18                 124.0  0.103806         0  0.219381
# 14                 160.0  0.671280         0  0.217398
# 11                 124.0  0.647059         1  0.185897
# 15                 160.0  0.802768         0  0.035330
# 4                  152.0  0.335640         0  0.024371
# 13                 160.0  0.602076         0  0.000752
# 8                  124.0  0.408304         0  0.000645
# 16                  14.0  0.543253         0  0.000580
# 0                  152.0  0.820069         0  0.000573
# 10                 152.0  0.072664         0  0.000569
# 12                  26.0  0.996540         0  0.000519
# 17                 152.0  0.681661         0  0.000510
# 9                   26.0  0.840830         0  0.000490
# 5                  152.0  0.463668         0  0.000463

# %%
test1 = [{"id":225916,"Gender":"Male","Age":69,"Driving_License":1,"Region_Code":28,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":34404,"Policy_Sales_Channel":124,"Vintage":30,"Response":0},{"id":108197,"Gender":"Male","Age":60,"Driving_License":1,"Region_Code":15,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":2630,"Policy_Sales_Channel":160,"Vintage":65,"Response":0},{"id":92008,"Gender":"Male","Age":41,"Driving_License":1,"Region_Code":3,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":73221,"Policy_Sales_Channel":26,"Vintage":289,"Response":0},{"id":191052,"Gender":"Male","Age":27,"Driving_License":1,"Region_Code":9,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":2630,"Policy_Sales_Channel":156,"Vintage":181,"Response":0},{"id":187752,"Gender":"Male","Age":41,"Driving_License":1,"Region_Code":28,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":30467,"Policy_Sales_Channel":13,"Vintage":270,"Response":0},{"id":216231,"Gender":"Female","Age":41,"Driving_License":1,"Region_Code":28,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":57802,"Policy_Sales_Channel":124,"Vintage":172,"Response":0},{"id":315908,"Gender":"Male","Age":68,"Driving_License":1,"Region_Code":8,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":72179,"Policy_Sales_Channel":26,"Vintage":274,"Response":0},{"id":172082,"Gender":"Female","Age":47,"Driving_License":1,"Region_Code":28,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":45620,"Policy_Sales_Channel":122,"Vintage":211,"Response":0},{"id":58502,"Gender":"Male","Age":44,"Driving_License":1,"Region_Code":7,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":40947,"Policy_Sales_Channel":124,"Vintage":98,"Response":0},{"id":244356,"Gender":"Male","Age":63,"Driving_License":1,"Region_Code":8,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":42146,"Policy_Sales_Channel":26,"Vintage":16,"Response":0}]

# %%
data
# Out:
# '[{"id":234405,"Gender":"Male","Age":23,"Driving_License":1,"Region_Code":12.0,"Previously_Insured":1,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"No","Annual_Premium":37993.0,"Policy_Sales_Channel":152.0,"Vintage":247,"Response":0},{"id":76475,"Gender":"Male","Age":33,"Driving_License":1,"Region_Code":28.0,"Previously_Insured":0,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"Yes","Annual_Premium":47109.0,"Policy_Sales_Channel":61.0,"Vintage":181,"Response":0},{"id":135198,"Gender":"Male","Age":66,"Driving_License":1,"Region_Code":28.0,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":2630.0,"Policy_Sales_Channel":157.0,"Vintage":247,"Response":0},{"id":130865,"Gender":"Female","Age":44,"Driving_License":1,"Region_Code":28.0,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":62857.0,"Policy_Sales_Channel":26.0,"Vintage":90,"Response":0},{"id":89191,"Gender":"Female","Age":48,"Driving_License":1,"Region_Code":30.0,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":24848.0,"Policy_Sales_Channel":152.0,"Vintage":107,"Response":0},{"id":378705,"Gender":"Female","Age":24,"Driving_License":1,"Region_Code":30.0,"Previously_Insured":1,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"No","Annual_Premium":31104.0,"Policy_Sales_Channel":152.0,"Vintage":144,"Response":0},{"id":247983,"Gender":"Male","Age":57,"Driving_License":1,"Region_Code":19.0,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":36319.0,"Policy_Sales_Channel":124.0,"Vintage":80,"Response":0},{"id":247562,"Gender":"Male","Age":48,"Driving_License":1,"Region_Code":28.0,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":47453.0,"Policy_Sales_Channel":124.0,"Vintage":59,"Response":1},{"id":288481,"Gender":"Female","Age":35,"Driving_License":1,"Region_Code":3.0,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":21915.0,"Policy_Sales_Channel":124.0,"Vintage":128,"Response":0},{"id":338846,"Gender":"Female","Age":45,"Driving_License":1,"Region_Code":30.0,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":40927.0,"Policy_Sales_Channel":26.0,"Vintage":253,"Response":0},{"id":187257,"Gender":"Female","Age":28,"Driving_License":1,"Region_Code":41.0,"Previously_Insured":1,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"No","Annual_Premium":25457.0,"Policy_Sales_Channel":152.0,"Vintage":31,"Response":0},{"id":27441,"Gender":"Female","Age":40,"Driving_License":1,"Region_Code":15.0,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":25799.0,"Policy_Sales_Channel":124.0,"Vintage":197,"Response":1},{"id":178646,"Gender":"Male","Age":67,"Driving_License":1,"Region_Code":17.0,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":41514.0,"Policy_Sales_Channel":26.0,"Vintage":298,"Response":0},{"id":8140,"Gender":"Male","Age":20,"Driving_License":1,"Region_Code":8.0,"Previously_Insured":1,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"No","Annual_Premium":33224.0,"Policy_Sales_Channel":160.0,"Vintage":184,"Response":0},{"id":32869,"Gender":"Female","Age":25,"Driving_License":1,"Region_Code":37.0,"Previously_Insured":0,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"Yes","Annual_Premium":34323.0,"Policy_Sales_Channel":160.0,"Vintage":204,"Response":0},{"id":169296,"Gender":"Male","Age":23,"Driving_License":1,"Region_Code":16.0,"Previously_Insured":0,"Vehicle_Age":"< 1 Year","Vehicle_Damage":"No","Annual_Premium":24644.0,"Policy_Sales_Channel":160.0,"Vintage":242,"Response":0},{"id":202884,"Gender":"Female","Age":38,"Driving_License":1,"Region_Code":15.0,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":33136.0,"Policy_Sales_Channel":14.0,"Vintage":167,"Response":0},{"id":294919,"Gender":"Female","Age":22,"Driving_License":1,"Region_Code":33.0,"Previously_Insured ...

# %%
test1
# Out:
# [{'id': 225916,
#   'Gender': 'Male',
#   'Age': 69,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34404,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 30,
#   'Response': 0},
#  {'id': 108197,
#   'Gender': 'Male',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 65,
#   'Response': 0},
#  {'id': 92008,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 73221,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 289,
#   'Response': 0},
#  {'id': 191052,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 9,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 181,
#   'Response': 0},
#  {'id': 187752,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30467,
#   'Policy_Sales_Channel': 13,
#   'Vintage': 270,
#   'Response': 0},
#  {'id': 216231,
#   'Gender': 'Female',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57802,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 172,
#   'Response': 0},
#  {'id': 315908,
#   'Gender': 'Male',
#   'Age': 68,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 72179,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 274,
#   'Response': 0},
#  {'id': 172082,
#   'Gender': 'Female',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 45620,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 211,
#   'Response': 0},
#  {'id': 58502,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 7,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40947,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 98,
#   'Response': 0},
#  {'id': 244356,
#   'Gender': 'Male',
#   'Age': 63,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42146,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 16,
#   'Response': 0}]

# %%
test1 = json.dumps(test1)

# %%
test1
# Out:
# '[{"id": 225916, "Gender": "Male", "Age": 69, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 34404, "Policy_Sales_Channel": 124, "Vintage": 30, "Response": 0}, {"id": 108197, "Gender": "Male", "Age": 60, "Driving_License": 1, "Region_Code": 15, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 2630, "Policy_Sales_Channel": 160, "Vintage": 65, "Response": 0}, {"id": 92008, "Gender": "Male", "Age": 41, "Driving_License": 1, "Region_Code": 3, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 73221, "Policy_Sales_Channel": 26, "Vintage": 289, "Response": 0}, {"id": 191052, "Gender": "Male", "Age": 27, "Driving_License": 1, "Region_Code": 9, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 2630, "Policy_Sales_Channel": 156, "Vintage": 181, "Response": 0}, {"id": 187752, "Gender": "Male", "Age": 41, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 30467, "Policy_Sales_Channel": 13, "Vintage": 270, "Response": 0}, {"id": 216231, "Gender": "Female", "Age": 41, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 57802, "Policy_Sales_Channel": 124, "Vintage": 172, "Response": 0}, {"id": 315908, "Gender": "Male", "Age": 68, "Driving_License": 1, "Region_Code": 8, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 72179, "Policy_Sales_Channel": 26, "Vintage": 274, "Response": 0}, {"id": 172082, "Gender": "Female", "Age": 47, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 45620, "Policy_Sales_Channel": 122, "Vintage": 211, "Response": 0}, {"id": 58502, "Gender": "Male", "Age": 44, "Driving_License": 1, "Region_Code": 7, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 40947, "Policy_Sales_Channel": 124, "Vintage": 98, "Response": 0}, {"id": 244356, "Gender": "Male", "Age": 63, "Driving_License": 1, "Region_Code": 8, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 42146, "Policy_Sales_Channel": 26, "Vintage": 16, "Response": 0}]'

# %%
url = 'https://health-insurance-web-app.onrender.com/predict'
header = {'Content-type': 'application/json'}

r = requests.post(url, json=test2, headers=header)
#r = requests.post(url=url, data=test1)
print(f'Status Code {r.status_code}')
# Out:
# Status Code 200

# %%
# Out:
# requests.models.Response

# %%
test2 = [{"id":225916,"Gender":"Male","Age":69,"Driving_License":1,"Region_Code":28,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":34404,"Policy_Sales_Channel":124,"Vintage":30,"Response":0},{"id":108197,"Gender":"Male","Age":60,"Driving_License":1,"Region_Code":15,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":2630,"Policy_Sales_Channel":160,"Vintage":65,"Response":0},{"id":92008,"Gender":"Male","Age":41,"Driving_License":1,"Region_Code":3,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":73221,"Policy_Sales_Channel":26,"Vintage":289,"Response":0},{"id":191052,"Gender":"Male","Age":27,"Driving_License":1,"Region_Code":9,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":2630,"Policy_Sales_Channel":156,"Vintage":181,"Response":0},{"id":187752,"Gender":"Male","Age":41,"Driving_License":1,"Region_Code":28,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":30467,"Policy_Sales_Channel":13,"Vintage":270,"Response":0},{"id":216231,"Gender":"Female","Age":41,"Driving_License":1,"Region_Code":28,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":57802,"Policy_Sales_Channel":124,"Vintage":172,"Response":0},{"id":315908,"Gender":"Male","Age":68,"Driving_License":1,"Region_Code":8,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":72179,"Policy_Sales_Channel":26,"Vintage":274,"Response":0},{"id":172082,"Gender":"Female","Age":47,"Driving_License":1,"Region_Code":28,"Previously_Insured":1,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"No","Annual_Premium":45620,"Policy_Sales_Channel":122,"Vintage":211,"Response":0},{"id":58502,"Gender":"Male","Age":44,"Driving_License":1,"Region_Code":7,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":40947,"Policy_Sales_Channel":124,"Vintage":98,"Response":0},{"id":244356,"Gender":"Male","Age":63,"Driving_License":1,"Region_Code":8,"Previously_Insured":0,"Vehicle_Age":"1-2 Year","Vehicle_Damage":"Yes","Annual_Premium":42146,"Policy_Sales_Channel":26,"Vintage":16,"Response":0}]

# %%
test2
# Out:
# '[{"id": 225916, "Gender": "Male", "Age": 69, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 34404, "Policy_Sales_Channel": 124, "Vintage": 30, "Response": 0}, {"id": 108197, "Gender": "Male", "Age": 60, "Driving_License": 1, "Region_Code": 15, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 2630, "Policy_Sales_Channel": 160, "Vintage": 65, "Response": 0}, {"id": 92008, "Gender": "Male", "Age": 41, "Driving_License": 1, "Region_Code": 3, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 73221, "Policy_Sales_Channel": 26, "Vintage": 289, "Response": 0}, {"id": 191052, "Gender": "Male", "Age": 27, "Driving_License": 1, "Region_Code": 9, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 2630, "Policy_Sales_Channel": 156, "Vintage": 181, "Response": 0}, {"id": 187752, "Gender": "Male", "Age": 41, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 30467, "Policy_Sales_Channel": 13, "Vintage": 270, "Response": 0}, {"id": 216231, "Gender": "Female", "Age": 41, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 57802, "Policy_Sales_Channel": 124, "Vintage": 172, "Response": 0}, {"id": 315908, "Gender": "Male", "Age": 68, "Driving_License": 1, "Region_Code": 8, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 72179, "Policy_Sales_Channel": 26, "Vintage": 274, "Response": 0}, {"id": 172082, "Gender": "Female", "Age": 47, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 45620, "Policy_Sales_Channel": 122, "Vintage": 211, "Response": 0}, {"id": 58502, "Gender": "Male", "Age": 44, "Driving_License": 1, "Region_Code": 7, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 40947, "Policy_Sales_Channel": 124, "Vintage": 98, "Response": 0}, {"id": 244356, "Gender": "Male", "Age": 63, "Driving_License": 1, "Region_Code": 8, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 42146, "Policy_Sales_Channel": 26, "Vintage": 16, "Response": 0}]'

# %%
type(test2)
# Out:
# str

# %%
test2 = json.dumps(test2)

# %%
json.loads(test2)
# Out:
# [{'id': 225916,
#   'Gender': 'Male',
#   'Age': 69,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34404,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 30,
#   'Response': 0},
#  {'id': 108197,
#   'Gender': 'Male',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 65,
#   'Response': 0},
#  {'id': 92008,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 73221,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 289,
#   'Response': 0},
#  {'id': 191052,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 9,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 181,
#   'Response': 0},
#  {'id': 187752,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30467,
#   'Policy_Sales_Channel': 13,
#   'Vintage': 270,
#   'Response': 0},
#  {'id': 216231,
#   'Gender': 'Female',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57802,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 172,
#   'Response': 0},
#  {'id': 315908,
#   'Gender': 'Male',
#   'Age': 68,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 72179,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 274,
#   'Response': 0},
#  {'id': 172082,
#   'Gender': 'Female',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 45620,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 211,
#   'Response': 0},
#  {'id': 58502,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 7,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40947,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 98,
#   'Response': 0},
#  {'id': 244356,
#   'Gender': 'Male',
#   'Age': 63,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42146,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 16,
#   'Response': 0}]

# %%
pd.json_normalize(test2)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.json_normalize(test2)
#
# File ~/.pyenv/versions/HICS/lib/python3.10/site-packages/pandas/io/json/_normalize.py:447, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     445     data = list(data)
#     446 else:
# --> 447     raise NotImplementedError
#     449 # check to see if a simple recursive function is possible to
#     450 # improve performance (see #15621) but only for cases such
#     451 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     452 if (
#     453     record_path is None
#     454     and meta is None
#    (...)
#     457     and max_level is None
#     458 ):
#
# NotImplementedError:
